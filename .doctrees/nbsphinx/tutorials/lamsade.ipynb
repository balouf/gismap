# %% [markdown]
# # LAMSADE

# %% [markdown]
# The *Laboratoire d’Analyse et de Modélisation de Systèmes pour l'Aide à la Décision* (LAMSADE) is the Computer Science lab of Paris Dauphine.

# %%
from gismap.lab_examples.lamsade import Lamsade
from gismap.utils.logger import logger
import logging

logger.setLevel(logging.ERROR)

lamsade = Lamsade()
lamsade.update_authors()
lamsade.update_publis()
lamsade.expand()
lamsade.show_html()
# Out:
# Author information: 0it [00:00, ?it/s]
# Publications information: 0it [00:00, ?it/s]
# <div class="gisgraph" id="box-9dacb6c1">
# 	<div id="vis-9dacb6c1">
# 	</div>
# 	<a href="https://balouf.github.io/gismap/" target="_blank" class="watermark gislink">&copy; GisMap 2025</a>
# 	<button id="redraw-9dacb6c1" class="watermark button redraw">Redraw()</button>
# 	<button id="fullscreen-9dacb6c1" class="watermark button fullscreen">Full Screen</button>
# 	<div class="modal" id="modal-9dacb6c1">
# 		<div class="modal-content">
# 			<span class="close" id="modal-close-9dacb6c1">&times;</span>
# 			<div id="modal-body-9dacb6c1">
# 			</div>
# 		</div>
# 	</div>
# </div>
#
# <style>
#
#                          #box-9dacb6c1 {
#                              position: relative;
#                              width: 100% !important;
#                              height: 80vh !important;
#                              max-width: 100vw !important;
# ...
