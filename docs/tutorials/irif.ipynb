# %% [markdown]
# # IRIF

# %% [markdown]
# The [Institut de Recherche en Informatique Fondamentale (IRIF)](https://www.irif.fr/) is the Computer Science lab of [Paris Cité](https://u-paris.fr/).

# %% [markdown]
# :::warning
# A very large map is displayed at the bottom of this page. Expect a lag in display.
# :::

# %% [markdown]
# There will be a lot of warnings in this notebook, so we disable them.

# %%
import logging
from gismap.utils.logger import logger

logger.setLevel(logging.ERROR)

# %% [markdown]
# ## Single team

# %%
from gismap.lab_examples.irif import IrifMap

combi = IrifMap("combi")
combi.update_authors()
combi.update_publis()
combi.expand()
combi.show_html()

# %% [markdown]
# ## Full view

# %%
from gismap.lab_examples.irif import IrifFull

irif = IrifFull()
irif.update_authors()
irif.update_publis()
irif.show_html()
