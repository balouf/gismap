# %% [markdown]
# # Cédric

# %% [markdown]
# The *Centre d’études et de recherche en informatique et communications* (Cédric) is the Computer Science lab of the [CNAM](https://www.cnam.fr/).

# %%
from gismap.lab_examples.cedric import CedricFull

# %%
cedric = CedricFull()
cedric.update_authors()
cedric.update_publis()
cedric.show_html()

# %%
cedric2 = CedricFull(dbs="ldb")
cedric2.update_authors()
cedric2.update_publis()
cedric2.show_html()
